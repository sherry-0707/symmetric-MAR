# %%
import torch
import numpy as np

N = 20
Sigma_half = torch.rand(N, N).numpy()
Sigma_half_symmetric = (Sigma_half+Sigma_half.T)/2
Sigma = Sigma_half_symmetric @ Sigma_half_symmetric
print(np.linalg.eig(Sigma))
# Out:
# EigResult(eigenvalues=array([1.01542175e+02, 3.26826739e+00, 2.52070475e+00, 1.97750103e+00,
#        1.74279213e+00, 1.47304034e+00, 1.27209699e+00, 8.85695457e-01,
#        7.25877047e-01, 7.78340995e-01, 7.71422088e-01, 4.18545872e-01,
#        2.50240862e-01, 4.21093340e-04, 9.42120235e-03, 2.79522333e-02,
#        6.25085160e-02, 1.10437550e-01, 1.41580209e-01, 1.36640877e-01],
#       dtype=float32), eigenvectors=array([[ 0.22870028,  0.27388266, -0.08097092,  0.05435   , -0.10077494,
#          0.44195655, -0.00612023, -0.18981065, -0.4173992 , -0.2079244 ,
#          0.1841544 , -0.33264714,  0.03306986,  0.01741529, -0.04389202,
#          0.28357404, -0.11302253, -0.02315633, -0.03471884,  0.4016904 ],
#        [ 0.21161899,  0.06742477,  0.07791968,  0.20293169,  0.02585313,
#          0.24326688,  0.00430301,  0.268967  , -0.10312484, -0.08700379,
#         -0.2589222 ,  0.03562609,  0.06098564,  0.07935239, -0.20473906,
# ...
